# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)

# %%
general_data = pd.read_csv('general-data.csv')
manager_survey_data = pd.read_csv('manager-survey-data.csv')
employee_survey_data = pd.read_csv('employee-survey-data.csv')
in_time = pd.read_csv('in-time.csv')
out_time = pd.read_csv('out-time.csv')

# %%
data_dictionary = pd.read_excel('data-dictionary.xlsx',engine='openpyxl')

# %%
data_dictionary
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %%
general_data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
manager_survey_data
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
employee_survey_data
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
in_time
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1              2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2              3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3              4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4              5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 09:20:32  2015-01-05 10:17:53
# 4406        4407         NaN  2015-01-02 10:03:41                  NaN
# 4407        4408         NaN  2015-01-02 10:01:01  2015-01-05 09:33:00
# 4408        4409         NaN  2015-01-02 10:17:05  2015-01-05 10:02:27
# 4409        4410         NaN  2015-01-02 09:59:09  2015-01-05 10:16:14
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %%
out_time
# Out:
#       Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0              1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1              2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2              3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3              4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4              5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
# ...          ...         ...                  ...                  ...
# 4405        4406         NaN  2015-01-02 17:27:37  2015-01-05 19:08:20
# 4406        4407         NaN  2015-01-02 16:19:01                  NaN
# 4407        4408         NaN  2015-01-02 17:17:35  2015-01-05 17:08:07
# 4408        4409         NaN  2015-01-02 19:48:37  2015-01-05 19:37:40
# 4409        4410         NaN  2015-01-02 16:49:19  2015-01-05 17:33:02
#
#                2015-01-06           2015-01-07           2015-01-08  \
# ...

# %%
#remove the columns that are complete null
in_time.dropna(how="all",axis=1,inplace=True)
out_time.dropna(how="all",axis=1,inplace=True)

# %%
in_time.fillna(0,inplace=True)
out_time.fillna(0,inplace=True)

# %%
total_time = in_time.append(out_time)

# %%
total_time
# Out:
#       Unnamed: 0           2015-01-02           2015-01-05  \
# 0              1  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1              2  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2              3  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3              4  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4              5  2015-01-02 10:28:17  2015-01-05 09:49:58
# ...          ...                  ...                  ...
# 4405        4406  2015-01-02 17:27:37  2015-01-05 19:08:20
# 4406        4407  2015-01-02 16:19:01                    0
# 4407        4408  2015-01-02 17:17:35  2015-01-05 17:08:07
# 4408        4409  2015-01-02 19:48:37  2015-01-05 19:37:40
# 4409        4410  2015-01-02 16:49:19  2015-01-05 17:33:02
#
#                2015-01-06           2015-01-07           2015-01-08  \
# 0     2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                       0  2015-01-07 09:45:17  2015-01-08 10:09:04
# ...

# %%
total_time.columns
# Out:
# Index(['Unnamed: 0', '2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#        '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-15',
#        ...
#        '2015-12-17', '2015-12-18', '2015-12-21', '2015-12-22', '2015-12-23',
#        '2015-12-24', '2015-12-28', '2015-12-29', '2015-12-30', '2015-12-31'],
#       dtype='object', length=250)

# %%
total_time.drop('Unnamed: 0',axis=1,inplace=True)

# %%
total_time
# Out:
#                2015-01-02           2015-01-05           2015-01-06  \
# 0     2015-01-02 09:43:45  2015-01-05 10:08:48  2015-01-06 09:54:26
# 1     2015-01-02 10:15:44  2015-01-05 10:21:05                    0
# 2     2015-01-02 10:17:41  2015-01-05 09:50:50  2015-01-06 10:14:13
# 3     2015-01-02 10:05:06  2015-01-05 09:56:32  2015-01-06 10:11:07
# 4     2015-01-02 10:28:17  2015-01-05 09:49:58  2015-01-06 09:45:28
# ...                   ...                  ...                  ...
# 4405  2015-01-02 17:27:37  2015-01-05 19:08:20  2015-01-06 18:50:49
# 4406  2015-01-02 16:19:01                    0  2015-01-06 15:07:37
# 4407  2015-01-02 17:17:35  2015-01-05 17:08:07  2015-01-06 17:27:46
# 4408  2015-01-02 19:48:37  2015-01-05 19:37:40  2015-01-06 20:00:08
# 4409  2015-01-02 16:49:19  2015-01-05 17:33:02  2015-01-06 16:36:10
#
#                2015-01-07           2015-01-08           2015-01-09  \
# 0     2015-01-07 09:34:31  2015-01-08 09:51:09  2015-01-09 10:09:25
# ...

# %%
total_time = total_time.apply(pd.to_datetime,errors='coerce')

# %%
total_time
# Out:
#               2015-01-02          2015-01-05          2015-01-06  \
# 0    2015-01-02 09:43:45 2015-01-05 10:08:48 2015-01-06 09:54:26
# 1    2015-01-02 10:15:44 2015-01-05 10:21:05 1970-01-01 00:00:00
# 2    2015-01-02 10:17:41 2015-01-05 09:50:50 2015-01-06 10:14:13
# 3    2015-01-02 10:05:06 2015-01-05 09:56:32 2015-01-06 10:11:07
# 4    2015-01-02 10:28:17 2015-01-05 09:49:58 2015-01-06 09:45:28
# ...                  ...                 ...                 ...
# 4405 2015-01-02 17:27:37 2015-01-05 19:08:20 2015-01-06 18:50:49
# 4406 2015-01-02 16:19:01 1970-01-01 00:00:00 2015-01-06 15:07:37
# 4407 2015-01-02 17:17:35 2015-01-05 17:08:07 2015-01-06 17:27:46
# 4408 2015-01-02 19:48:37 2015-01-05 19:37:40 2015-01-06 20:00:08
# 4409 2015-01-02 16:49:19 2015-01-05 17:33:02 2015-01-06 16:36:10
#
#               2015-01-07          2015-01-08          2015-01-09  \
# 0    2015-01-07 09:34:31 2015-01-08 09:51:09 2015-01-09 10:09:25
# ...

# %%
total_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8820 entries, 0 to 4409
# Columns: 249 entries, 2015-01-02 to 2015-12-31
# dtypes: datetime64[ns](249)
# memory usage: 16.8 MB

# %%
total_time = total_time.diff(periods=4410)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0                NaT             NaT             NaT             NaT
# 1                NaT             NaT             NaT             NaT
# 2                NaT             NaT             NaT             NaT
# 3                NaT             NaT             NaT             NaT
# 4                NaT             NaT             NaT             NaT
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time = total_time.iloc[4410:]

# %%
total_time['mean_time'] = total_time.mean(axis=1)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1    0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time['mean_time'] = total_time['mean_time'].dt.total_seconds()/(3600.0)

# %%
total_time
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1    0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
total_time = total_time.reset_index()

# %%
total_time
# Out:
#       index      2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 0         0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 1         1 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 2         2 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 3         3 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 4         4 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...     ...             ...             ...             ...             ...
# 4405   4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4406   4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37 0 days 05:43:40
# 4407   4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4408   4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4409   4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
# ...

# %%
total_time = total_time.rename(columns={'index':'EmployeeID'})

# %%
total_time
# Out:
#       EmployeeID      2015-01-02      2015-01-05      2015-01-06  \
# 0              0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39
# 1              1 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00
# 2              2 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19
# 3              3 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35
# 4              4 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57
# ...          ...             ...             ...             ...
# 4405        4405 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58
# 4406        4406 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37
# 4407        4407 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29
# 4408        4408 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18
# 4409        4409 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40
#
#           2015-01-07      2015-01-08      2015-01-09      2015-01-12  \
# 0    0 days 07:00:24 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46
# ...

# %%
total_time['EmployeeID'] = total_time.EmployeeID + 1

# %%
total_time
# Out:
#       EmployeeID      2015-01-02      2015-01-05      2015-01-06  \
# 0              1 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39
# 1              2 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00
# 2              3 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19
# 3              4 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35
# 4              5 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57
# ...          ...             ...             ...             ...
# 4405        4406 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58
# 4406        4407 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37
# 4407        4408 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29
# 4408        4409 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18
# 4409        4410 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40
#
#           2015-01-07      2015-01-08      2015-01-09      2015-01-12  \
# 0    0 days 07:00:24 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46
# ...

# %%
total_time = total_time[['EmployeeID','mean_time']]

# %%
total_time
# Out:
#       EmployeeID  mean_time
# 0              1   6.870229
# 1              2   7.315971
# 2              3   6.816081
# 3              4   6.789215
# 4              5   7.877561
# ...          ...        ...
# 4405        4406   8.316921
# 4406        4407   5.897197
# 4407        4408   7.149526
# 4408        4409   9.187612
# 4409        4410   6.511790
#
# [4410 rows x 2 columns]

# %%
df = pd.merge(general_data,manager_survey_data,how='inner',on='EmployeeID')

# %%
df = pd.merge(df,employee_survey_data,how='inner',on='EmployeeID')

# %%
df = pd.merge(df, total_time, how='inner',on='EmployeeID')

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
df.drop(['EmployeeCount','StandardHours'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# JobInvolvement              0
# PerformanceRating           0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# mean_time                   0
# dtype: int64

# %%
obj_cols = df.select_dtypes(include='object').columns

# %%
obj_cols
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18'],
#       dtype='object')

# %%
for i in obj_cols:
    unique_values = len(df[i].value_counts())
    if unique_values == 1:
        print(i)
# Out:
# Over18

# %%
df.drop(['Over18'],axis=1,inplace=True)

# %%
df['newquery'] = df['mean_time']>8

# %%
df[df['newquery']==True]['EmployeeID']
# Out:
# 5          6
# 10        11
# 12        13
# 13        14
# 17        18
#         ...
# 4387    4388
# 4389    4390
# 4391    4392
# 4405    4406
# 4408    4409
# Name: EmployeeID, Length: 1069, dtype: int64

# %%
for i in df.mean_time:
    if i>8:
        print (df[df['mean_time']==i]['EmployeeID'])
# Out:
# 5    6
# Name: EmployeeID, dtype: int64
# 10    11
# Name: EmployeeID, dtype: int64
# 12    13
# Name: EmployeeID, dtype: int64
# 13    14
# Name: EmployeeID, dtype: int64
# 17    18
# Name: EmployeeID, dtype: int64
# 19    20
# Name: EmployeeID, dtype: int64
# 25    26
# Name: EmployeeID, dtype: int64
# 26    27
# Name: EmployeeID, dtype: int64
# 28    29
# Name: EmployeeID, dtype: int64
# 30    31
# Name: EmployeeID, dtype: int64
# 32    33
# Name: EmployeeID, dtype: int64
# 35    36
# Name: EmployeeID, dtype: int64
# 36    37
# Name: EmployeeID, dtype: int64
# 50    51
# Name: EmployeeID, dtype: int64
# 51    52
# Name: EmployeeID, dtype: int64
# 54    55
# Name: EmployeeID, dtype: int64
# 56    57
# Name: EmployeeID, dtype: int64
# 58    59
# Name: EmployeeID, dtype: int64
# 60    61
# Name: EmployeeID, dtype: int64
# 61    62
# Name: EmployeeID, dtype: int64
# 62    63
# Name: EmployeeID, dtype: int64
# 65    66
# Name: EmployeeID, dtype: int64
# 69    70
# ...

# %%
plt.figure(figsize=(18,5))
a = sns.countplot(x='NumCompaniesWorked',data=df)

# %%
df['NumCompaniesWorked'].fillna(1.0,inplace=True)

# %%
plt.figure(figsize=(18,5))
a = sns.countplot(x='TotalWorkingYears',data=df)

# %%
df['TotalWorkingYears'].fillna(10.0,inplace=True)

# %%
plt.figure(figsize=(18,5))
a = sns.countplot(x='EnvironmentSatisfaction',data=df)

# %%
df['EnvironmentSatisfaction'].fillna(3.0,inplace=True)

# %%
plt.figure(figsize=(18,5))
a = sns.countplot(x='JobSatisfaction',data=df)

# %%
df['JobSatisfaction'].fillna(4.0,inplace=True)

# %%
plt.figure(figsize=(18,5))
a = sns.countplot(x='WorkLifeBalance',data=df)

# %%
df['WorkLifeBalance'].fillna(3.0,inplace=True)

# %%
def makingplot(feature):
    plt.figure(figsize=(18,10))
    sns.countplot(x=feature,hue='Attrition',data=df)
    plt.xlabel(feature)
    plt.title('{} vs attrition'.format(feature))

# %%
makingplot("TotalWorkingYears")

# %%
makingplot("BusinessTravel")

# %%
makingplot("Department")

# %%
makingplot('Education')

# %%
makingplot("Gender")

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeID', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'JobInvolvement', 'PerformanceRating',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'mean_time', 'newquery'],
#       dtype='object')

# %%
makingplot('WorkLifeBalance')

# %%
makingplot("JobSatisfaction")

# %%
makingplot("JobSatisfaction")

# %%
makingplot("YearsSinceLastPromotion")

# %%
makingplot('newquery')

# %%
makingplot('JobInvolvement')

# %%
makingplot('JobLevel')

# %%
data_dictionary
# Out:
#                     Variable  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                 Department
# 4           DistanceFromHome
# 5                  Education
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10            EducationField
# 11             EmployeeCount
# 12            EmployeeNumber
# 13   EnvironmentSatisfaction
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                    Gender
# 18            JobInvolvement
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                  JobLevel
# 23                   JobRole
# 24           JobSatisfaction
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28             MaritalStatus
# 29             MonthlyIncome
# 30        NumCompaniesWorked
# ...

# %%
###### feature engineering
## encoding - one hot encoding
one_hot_var = ['BusinessTravel', 'Department', 'EducationField','JobRole', 'MaritalStatus']
for i in one_hot_var:
    x_t = pd.get_dummies(df[i],prefix=i,prefix_sep='_',drop_first=True)
    df = df.join(x_t)
    df.drop(i,axis=1,inplace=True)

# %%
df.Attrition = df.Attrition.apply(lambda x: 1 if x=='Yes' else 0)
df.Gender = df.Gender.apply(lambda x: 1 if x=='Male' else 0)

# %%
df
# Out:
#       Age  Attrition  DistanceFromHome  Education  EmployeeID  Gender  \
# 0      51          0                 6          2           1       0
# 1      31          1                10          1           2       0
# 2      32          0                17          4           3       1
# 3      38          0                 2          5           4       1
# 4      32          0                10          1           5       1
# ...   ...        ...               ...        ...         ...     ...
# 4405   42          0                 5          4        4406       0
# 4406   29          0                 2          4        4407       1
# 4407   25          0                25          2        4408       1
# 4408   42          0                18          2        4409       1
# 4409   40          0                28          3        4410       1
#
#       JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# ...

# %%
### Multicollinearity check
## find the columns which have correlation more than 0.8
df.corr().shape[1]
# Out:
# 42

# %%
df_corr = df.corr()
for i in range(df_corr.shape[0]):
    for j in range(df_corr.shape[1]):
        if (abs(df_corr.iloc[i,j])>0.8) & (abs(df_corr.iloc[i,j])!=1):
            print(round(df_corr.iloc[i,j],3),df_corr.columns[j],'&', df_corr.index[i])
# Out:
# 0.855 newquery & mean_time
# 0.855 mean_time & newquery
# -0.907 Department_Sales & Department_Research & Development
# -0.907 Department_Research & Development & Department_Sales

# %%
df[['newquery','mean_time','Department_Sales','Department_Research & Development','Attrition']].corr()
# Out:
#                                    newquery  mean_time  Department_Sales  \
# newquery                           1.000000   0.855041         -0.028011
# mean_time                          0.855041   1.000000         -0.033274
# Department_Sales                  -0.028011  -0.033274          1.000000
# Department_Research & Development  0.015738   0.028691         -0.906818
# Attrition                          0.208140   0.198890         -0.019742
#
#                                    Department_Research & Development  \
# newquery                                                    0.015738
# mean_time                                                   0.028691
# Department_Sales                                           -0.906818
# Department_Research & Development                           1.000000
# Attrition                                                  -0.015307
#
#                                    Attrition
# newquery                            0.208140
# ...

# %%
df.drop(['mean_time','Department_Research & Development'],axis=1,inplace=True)

# %%
df
# Out:
#       Age  Attrition  DistanceFromHome  Education  EmployeeID  Gender  \
# 0      51          0                 6          2           1       0
# 1      31          1                10          1           2       0
# 2      32          0                17          4           3       1
# 3      38          0                 2          5           4       1
# 4      32          0                10          1           5       1
# ...   ...        ...               ...        ...         ...     ...
# 4405   42          0                 5          4        4406       0
# 4406   29          0                 2          4        4407       1
# 4407   25          0                25          2        4408       1
# 4408   42          0                18          2        4409       1
# 4409   40          0                28          3        4410       1
#
#       JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# ...

# %%
df.Attrition.value_counts()
# Out:
# 0    3699
# 1     711
# Name: Attrition, dtype: int64

# %%
df.Attrition.value_counts()
# Out:
# 0    3699
# 1     711
# Name: Attrition, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
x = df.drop('Attrition',axis=1)  #independent data
y = df['Attrition']  #dependent data

# %%
smote = SMOTE(sampling_strategy='minority')
x_sm,y_sm = smote.fit_resample(x,y)

# %%
y_sm.value_counts()
# Out:
# 0    3699
# 1    3699
# Name: Attrition, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_sm,y_sm,test_size=0.3,random_state=24)

# %%
x_train
# Out:
#       Age  DistanceFromHome  Education  EmployeeID  Gender  JobLevel  \
# 3807   29                 5          1        3808       0         1
# 4267   37                 6          1        4268       1         1
# 6256   35                10          3        3989       1         1
# 4117   44                 8          1        4118       0         1
# 5375   45                 1          2         980       0         3
# ...   ...               ...        ...         ...     ...       ...
# 3473   35                 7          4        3474       1         3
# 343    40                 9          3         344       1         3
# 6336   29                 5          3        2307       0         1
# 899    35                29          3         900       0         2
# 4514   35                 7          2        1885       0         1
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
ml = DecisionTreeClassifier()
ml.fit(x_train,y_train)
y_pred = ml.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1127
#            1       0.98      0.95      0.96      1093
#
#     accuracy                           0.96      2220
#    macro avg       0.96      0.96      0.96      2220
# weighted avg       0.96      0.96      0.96      2220

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1127
#            1       1.00      0.98      0.99      1093
#
#     accuracy                           0.99      2220
#    macro avg       0.99      0.99      0.99      2220
# weighted avg       0.99      0.99      0.99      2220

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72      1127
#            1       0.72      0.67      0.69      1093
#
#     accuracy                           0.71      2220
#    macro avg       0.71      0.71      0.71      2220
# weighted avg       0.71      0.71      0.71      2220
